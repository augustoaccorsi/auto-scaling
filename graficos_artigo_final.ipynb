# %% [markdown]
# <a href="https://colab.research.google.com/github/augustoaccorsi/autoscaling/blob/main/graficos_artigo_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
data_xls = pd.read_excel('/content/vms.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netin.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netout.xlsx', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('/content/csvfile.csv', encoding='utf-8', index=False) 
df=pd.read_csv('/content/csvfile.csv')

df=df.dropna()
print('Shape of data',df.shape)
#df.head()
df.tail()
# Out:
# Shape of data (299, 17)
#      tempo  aws1  aws2  aws3  ...  hy1  hy2  hy3  Cenário 4: Hybrelastic
# 295    296     4     3     4  ...    1    1    1                       3
# 296    297     4     3     3  ...    1    1    1                       3
# 297    298     4     2     3  ...    1    1    1                       3
# 298    299     4     2     3  ...    1    1    1                       3
# 299    300     4     2     3  ...    1    1    1                       3
#
# [5 rows x 17 columns]

# %%
df.drop('aws1', axis =1, inplace = True)
df.drop('aws2', axis =1, inplace = True)
df.drop('aws3', axis =1, inplace = True)

df.drop('hy1', axis =1, inplace = True)
df.drop('hy2', axis =1, inplace = True)
df.drop('hy3', axis =1, inplace = True)

df.drop('cpu1', axis =1, inplace = True)
df.drop('cpu2', axis =1, inplace = True)
df.drop('cpu3', axis =1, inplace = True)

df.drop('rede1', axis =1, inplace = True)
df.drop('rede2', axis =1, inplace = True)
df.drop('rede3', axis =1, inplace = True)

df.drop('tempo', axis =1, inplace = True)

# %%
ax = df.plot(figsize=(12,5))

ax.set_ylabel("Número de VMs")
ax.set_xlabel("Tempo de Execução (minutos)")
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=4)
plt.show()

# %%
data_xls = pd.read_excel('/content/micro.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netin.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netout.xlsx', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('/content/csvfile.csv', encoding='utf-8', index=False) 
df=pd.read_csv('/content/csvfile.csv')

df=df.dropna()
print('Shape of data',df.shape)
#df.head()

#df.drop('tempo', axis =1, inplace = True)



ax = df.plot(figsize=(12,5), color=['red', 'darkblue'])

#ax1 = df.ms1.plot(label='Microsserviço 1', color='red')
#ax2 = df.ms2.plot(label='Microsserviço 2', color='darkblue')


ax.set_ylabel("Máquinas Virtuais")
#ax.set_xlabel("Tempo de Execução (minutos)")

ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.02), ncol=4)

ax.grid('on', which='minor', axis='y' )
ax.grid('off', which='major', axis='y' )

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

plt.gca().axes.yaxis.set_ticklabels([])
plt.gca().axes.xaxis.set_ticklabels([])


plt.show()
# Out:
# Shape of data (147, 2)

# %%
'''
df.drop('net', axis =1, inplace = True)
df.drop('net_up', axis =1, inplace = True)
df.drop('net_down', axis =1, inplace = True)
'''
# Out:
# "\ndf.drop('net', axis =1, inplace = True)\ndf.drop('net_up', axis =1, inplace = True)\ndf.drop('net_down', axis =1, inplace = True)\n"

# %%
'''
ax = df.plot(figsize=(12,3))


plt.show()
'''
# Out:
# '\nax = df.plot(figsize=(12,3))\n\n\nplt.show()\n'

# %%
data_xls = pd.read_excel('/content/cpu.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netin.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netout.xlsx', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('/content/csvfile.csv', encoding='utf-8', index=False) 
df=pd.read_csv('/content/csvfile.csv')

df_cpu=df.dropna()
print('Shape of data',df_cpu.shape)
#df.head()
df_cpu.tail()
# Out:
# Shape of data (218, 4)
#           CPU  Limiar Superior  Limiar Inferior  instancias
# 213  26.50000             66.0        34.248650         2.0
# 214  29.87975             65.0        32.079825         2.0
# 215  23.59430             65.0        32.079825         1.0
# 216  23.59430             65.0        29.895375         1.0
# 217  23.00000             57.0        28.189875         1.0

# %%
data_xls = pd.read_excel('/content/net.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netin.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netout.xlsx', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('/content/csvfile.csv', encoding='utf-8', index=False) 
df=pd.read_csv('/content/csvfile.csv')

df_net=df.dropna()
print('Shape of data',df_net.shape)
#df.head()
df_net.tail()
# Out:
# Shape of data (218, 4)
#          Rede  Limiar Superior  Limiar Inferior  instancias
# 213   92.3090            160.0           92.968           2
# 214   94.5915            160.0           92.998           2
# 215   95.8140            160.0           93.158           1
# 216   95.8140            160.0           93.158           1
# 217  166.0880            160.0           93.158           1

# %%
#ax1 = df.plot(y=["cpu", "up_cpu", "down_cpu"])
#ax2 = df.plot(y=["net", "net_up", "net_down"])

df_cpu.drop('instancias', axis =1, inplace = True)
df_net.drop('instancias', axis =1, inplace = True)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# create dummy pandas dataframes
pd1 = df_cpu
pd2 = df_net
#create subplot figure with having two side by side plots
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,2.5))
# plot first pandas frame in subplot style
pd1.plot(ax = axes[0], color=['purple', 'darkblue', 'yellow'])
# plot second pandas frame in subplot style
axes[0].get_legend().remove()
axes[0].set_xlabel('Tempo de Execução (minutos)')
axes[0].set_ylabel('Utilização de CPU')
axes[1].set_xlabel('Tempo de Execução (minutos)')
axes[1].set_ylabel('Consumo de Rede')

pd2.plot(ax = axes[1])

h1, l1 = axes[0].get_legend_handles_labels()
h2, l2 = axes[1].get_legend_handles_labels()

#plt.legend(h1+h2, l1+l2, bbox_to_anchor=(0.0, 0.0))
plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(-0.1, -0.22), ncol=6)

plt.show()

# %%
data_xls = pd.read_excel('/content/netcpu.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netin.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netout.xlsx', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('/content/csvfile.csv', encoding='utf-8', index=False) 
df=pd.read_csv('/content/csvfile.csv')

df_net=df.dropna()
print('Shape of data',df_net.shape)
#df.head()
df_net.tail()
# Out:
# Shape of data (218, 4)
#      Unnamed: 0       net       cpu  instancias
# 213         214   92.3090  26.50000         2.0
# 214         215   94.5915  29.87975         2.0
# 215         216   95.8140  23.59430         1.0
# 216         217   95.8140  23.59430         1.0
# 217         218  166.0880  23.00000         1.0

# %%
import matplotlib.ticker as mticker


plt.figure(figsize=(12,2.5))
plt.xlabel('Tempo de Execução (minutos)')
plt.ylabel('Métricas')

ax1 = df.net.plot(grid=True, label='Rede (eixo y à esquerda)', color='orange')
ax1 = df.cpu.plot(grid=True, label='CPU (eixo y à esquerda)', color='green')

plt.vlines(x=46, ymin=0, ymax=73, ls='--', label='Pontos onde uma VM é alocada')
plt.vlines(x=75, ymin=0, ymax=73, ls='--')
plt.vlines(x=60, ymin=0, ymax=160, ls='--', color='red', label='Pontos onde uma VM é desalocada')
plt.vlines(x=87, ymin=0, ymax=160, ls='--', color='red')

ax2 = df.instancias.plot(secondary_y=True, label='VMs (eixo y à direita)', color='darkblue')
ax2.set_ylim(bottom=0)
#ax2.set_ylim(top=3)
plt.ylabel("Número de VMs")
plt.gca().yaxis.set_major_locator(mticker.MultipleLocator(1))

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()



#plt.legend(h1+h2, l1+l2, bbox_to_anchor=(0.0, 0.0))
plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=4)



plt.show()

# %%
data_xls = pd.read_excel('/content/aws.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netin.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netout.xlsx', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('/content/csvfile.csv', encoding='utf-8', index=False) 
df=pd.read_csv('/content/csvfile.csv')

df_net=df.dropna()
print('Shape of data',df_net.shape)
#df.head()
df_net.tail()
# Out:
# Shape of data (510, 4)
#          CPU  VMs  up  inf
# 505  10.0000    1  70   30
# 506  10.0000    1  70   30
# 507  10.0000    1  70   30
# 508  10.0000    1  70   30
# 509   9.8361    1  70   30

# %%
import matplotlib.ticker as mticker


plt.figure(figsize=(12,2.5))
plt.xlabel('Tempo de Execução (minutos)')
plt.ylabel('Métricas')

ax1 = df.CPU.plot(grid=True, label='CPU (eixo y à esquerda)', color='red')
ax1 = df.up.plot(grid=True, label='Limiar Superior (eixo y à esquerda)')
ax1 = df.inf.plot(grid=True, label='Limiar Inferior (eixo y à esquerda)')
ax2 = df.VMs.plot(secondary_y=True, label='VMs (eixo y à direita)', color='purple')
ax2.set_ylim(bottom=0)
#ax2.set_ylim(top=3)
plt.ylabel("Número de VMs")
plt.gca().yaxis.set_major_locator(mticker.MultipleLocator(1))

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()

plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=4)

plt.show()

# %%
data_xls = pd.read_excel('/content/bigpicture.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netin.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netout.xlsx', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('/content/csvfile.csv', encoding='utf-8', index=False) 
df=pd.read_csv('/content/csvfile.csv')

df_net=df.dropna()
print('Shape of data',df_net.shape)
#df.head()
df_net.tail()
# Out:
# Shape of data (7, 8)
#     tempo  MS1  MS2  MS3     engine         db   requests  Unnamed: 7
# 15     16    2    1    1  43.207399  50.479178  93.686577         3.0
# 16     17    3    1    1  57.908138  31.191832  89.099970         4.0
# 17     18    3    1    1  58.043939  31.614160  89.658099         5.0
# 18     19    3    1    1  59.939199  17.060799  76.999998         6.0
# 19     20    4    1    1  59.963468  11.244429  71.207897         7.0

# %%
import matplotlib.ticker as mticker


plt.figure(figsize=(10,10))
plt.xlabel('Tempo de Execução')
plt.ylabel("Número de VMs")

ax2 = df.requests.plot(secondary_y=True, label='Engine')
ax1 = df.MS1.plot(grid=False, label='MS1')
ax1 = df.MS2.plot(grid=False, label='MS2')
ax1 = df.MS3.plot(grid=False, label='MS3')
#ax2 = df.db.plot(secondary_y=True, label='DB')

ax1.grid(axis='y')

ax1.set_yticklabels([])
ax1.set_xticklabels([])

#ax2 = df.VMs.plot(secondary_y=True, label='VMs (direita)')
#ax2.set_ylim(bottom=0)
#ax2.set_ylim(top=3)
plt.gca().yaxis.set_major_locator(mticker.MultipleLocator(1))

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()


plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=4)

plt.show()

# %%
data_xls = pd.read_excel('/content/db-rede.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netin.xlsx', 'Sheet1', dtype=str, index_col=None)
#data_xls = pd.read_excel('/content/netout.xlsx', 'Sheet1', dtype=str, index_col=None)
data_xls.to_csv('/content/csvfile.csv', encoding='utf-8', index=False) 
df=pd.read_csv('/content/csvfile.csv')

df_net=df.dropna()
print('Shape of data',df_net.shape)
#df.head()
df_net.tail()
# Out:
# Shape of data (0, 26)
# Empty DataFrame
# Columns: [min, cpu, net, cup, cdown, nup, ndown, vms, CPU UP, CPU DOWN, NET UP, NET DOWN, Unnamed: 12, Unnamed: 13, Unnamed: 14, cpu1, net1, cup1, cdown1, nup1, ndown1, vms1, CPU UP.1, CPU DOWN.1, NET UP.1, NET DOWN.1]
# Index: []

# %%
import matplotlib.ticker as mticker


plt.figure(figsize=(12,2.5))
plt.xlabel('Tempo de Execução (minutos)')
plt.ylabel('Consumo de Rede')

ax1.set_title("This is my title")
ax1 = df.net.plot(grid=False, label='Rede (eixo y à esquerda)', color='purple')
#ax1 = df.cpu.plot(grid=False, label='CPU (esquerda)')
#ax1 = df.cup.plot(grid=False, label='CPU up')
#ax1 = df.cdown.plot(grid=False, label='CPU down')
ax1 = df.nup.plot(grid=False, label='Limiar Superior (eixo y à esquerda)')
ax1 = df.ndown.plot(grid=False, label='Limiar Inferior (eixo y à esquerda)')

#plt.vlines(x=46, ymin=0, ymax=73, ls='--', label='Pontos onde uma VM é alocada')
#plt.vlines(x=75, ymin=0, ymax=73, ls='--')
#plt.vlines(x=60, ymin=0, ymax=160, ls='--', color='red', label='Pontos onde uma VM é desalocada')
#plt.vlines(x=87, ymin=0, ymax=160, ls='--', color='red')

#up
plt.plot(22,32,'ro', label='Possível Alocação de VM')
plt.plot(24,36,'ro')
plt.plot(25,35,'ro') 
#up
plt.plot(30,35,'ro')
plt.plot(31,37,'ro')
#plt.plot(31,27,'ro')
#up
plt.plot(33,87,'ro')
plt.plot(34,40,'ro')
plt.plot(35,41,'ro') 
#down
plt.plot(49,26,'bo', label='Possível Desalocação de VM')
plt.plot(50,32,'bo')
plt.plot(51,29,'bo') 
#down
plt.plot(52,28,'bo')
plt.plot(53,26,'bo')
plt.plot(54,26,'bo') 
#down
plt.plot(55,25,'bo')
plt.plot(56,25,'bo')
plt.plot(57,26,'bo') 

plt.plot(30.5,35, 'o', ms=40, markerfacecolor="None", markeredgecolor='yellow', markeredgewidth=3)
plt.plot(0,80, 'o', ms=8, markerfacecolor="None", markeredgecolor='yellow', markeredgewidth=3, label='Combinação de Métricas')

ax2 = df.vms.plot(secondary_y=True, label='VMs (eixo y à direita)')
ax2.set_ylim(bottom=0)
ax2.set_ylim(top=6)

plt.ylabel("Número de VMs")
plt.gca().yaxis.set_major_locator(mticker.MultipleLocator(1))

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()




#plt.legend(h1+h2, l1+l2, bbox_to_anchor=(0.0, 0.0))
#plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=6)
plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(1.20, 1), ncol=1)
#plt.legend(h1, l1, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=7)



plt.show()

import matplotlib.ticker as mticker


plt.figure(figsize=(12,2.5))
plt.xlabel('Tempo de Execução (minutos)')
plt.ylabel('Utilização de CPU')

#ax1 = df.net.plot(grid=False, label='Rede (esquerda)')
ax3 = df.cpu1.plot(grid=False, label='CPU (eixo y à esquerda)', color='purple')
ax3 = df.cup1.plot(grid=False, label='Limiar Superior (eixo y à esquerda)')
ax3 = df.cdown1.plot(grid=False, label='Limiar Inferior (eixo y à esquerda)')
#ax3 = df.nup.plot(grid=False, label='Rede up')
#ax3 = df.ndown.plot(grid=False, label='Rede down')

#plt.vlines(x=46, ymin=0, ymax=73, ls='--', label='Pontos onde uma VM é alocada')
#plt.vlines(x=75, ymin=0, ymax=73, ls='--')
#plt.vlines(x=60, ymin=0, ymax=160, ls='--', color='red', label='Pontos onde uma VM é desalocada')
#plt.vlines(x=87, ymin=0, ymax=160, ls='--', color='red')

#up
plt.plot(6,55,'ro', label='Possível Alocação de VM')
plt.plot(7,56,'ro')
plt.plot(8,70,'ro') 
#dow
plt.plot(17,32,'bo', label='Possível Desalocação de VM')
plt.plot(18,0,'bo')
plt.plot(19,0,'bo')
#up
plt.plot(34,86,'ro')
plt.plot(35,75,'ro')
#plt.plot(35,41,'ro') 
#down
plt.plot(44,34,'bo')
plt.plot(45,0,'bo')
plt.plot(46,0,'bo') 
#up
plt.plot(58,54,'ro')
plt.plot(59,69,'ro')
plt.plot(60,100,'ro') 

plt.plot(34,80, 'o', ms=40, markerfacecolor="None", markeredgecolor='yellow', markeredgewidth=3)
plt.plot(0,80, 'o', ms=8, markerfacecolor="None", markeredgecolor='yellow', markeredgewidth=3, label='Combinação de Métricas')

ax4 = df.vms1.plot(secondary_y=True, label='VMs (eixo y à direita)')
ax4.set_ylim(bottom=0)
ax4.set_ylim(top=6)

plt.ylabel("Número de VMs")
plt.gca().yaxis.set_major_locator(mticker.MultipleLocator(1))

h1, l1 = ax3.get_legend_handles_labels()
h2, l2 = ax4.get_legend_handles_labels()




#plt.legend(h1+h2, l1+l2, bbox_to_anchor=(0.0, 0.0))
plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(1.20, 1), ncol=1)
#plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=6)
#plt.legend(h1, l1, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=7)



plt.show()

# %%
import matplotlib.ticker as mticker


plt.figure(figsize=(12,2.5))
plt.xlabel('Tempo de Execução (minutos)')
plt.ylabel('Consumo de Rede')

ax1.set_title("This is my title")
ax1 = df.net.plot(grid=False, label='Rede (eixo y à esquerda)', color='purple')
#ax1 = df.cpu.plot(grid=False, label='CPU (esquerda)')
#ax1 = df.cup.plot(grid=False, label='CPU up')
#ax1 = df.cdown.plot(grid=False, label='CPU down')
ax1 = df.nup.plot(grid=False, label='Limiar Superior (eixo y à esquerda)')
ax1 = df.ndown.plot(grid=False, label='Limiar Inferior (eixo y à esquerda)')

#plt.vlines(x=46, ymin=0, ymax=73, ls='--', label='Pontos onde uma VM é alocada')
#plt.vlines(x=75, ymin=0, ymax=73, ls='--')
#plt.vlines(x=60, ymin=0, ymax=160, ls='--', color='red', label='Pontos onde uma VM é desalocada')
#plt.vlines(x=87, ymin=0, ymax=160, ls='--', color='red')

#up
plt.plot(22,32,'ro', label='Possível Alocação de VM')
plt.plot(24,36,'ro')
plt.plot(25,35,'ro') 
#up
plt.plot(30,35,'ro')
plt.plot(31,37,'ro')
#plt.plot(31,27,'ro')
#up
plt.plot(33,87,'ro')
plt.plot(34,40,'ro')
plt.plot(35,41,'ro') 
#down
plt.plot(49,26,'bo', label='Possível Desalocação de VM')
plt.plot(50,32,'bo')
plt.plot(51,29,'bo') 
#down
plt.plot(52,28,'bo')
plt.plot(53,26,'bo')
plt.plot(54,26,'bo') 
#down
plt.plot(55,25,'bo')
plt.plot(56,25,'bo')
plt.plot(57,26,'bo') 

#plt.plot(30.5,35, 'o', ms=40, markerfacecolor="None", markeredgecolor='yellow', markeredgewidth=3)
#plt.plot(0,80, 'o', ms=8, markerfacecolor="None", markeredgecolor='yellow', markeredgewidth=3, label='Combinação de Métricas')

ax2 = df.vms.plot(secondary_y=True, label='VMs (eixo y à direita)')
ax2.set_ylim(bottom=0)
ax2.set_ylim(top=6)

plt.ylabel("Número de VMs")
plt.gca().yaxis.set_major_locator(mticker.MultipleLocator(1))

h1, l1 = ax1.get_legend_handles_labels()
h2, l2 = ax2.get_legend_handles_labels()




#plt.legend(h1+h2, l1+l2, bbox_to_anchor=(0.0, 0.0))
#plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=6)
plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(1.20, 1), ncol=1)
#plt.legend(h1, l1, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=7)



plt.show()

import matplotlib.ticker as mticker


plt.figure(figsize=(12,2.5))
plt.xlabel('Tempo de Execução (minutos)')
plt.ylabel('Utilização de CPU')

#ax1 = df.net.plot(grid=False, label='Rede (esquerda)')
ax3 = df.cpu1.plot(grid=False, label='CPU (eixo y à esquerda)', color='purple')
ax3 = df.cup1.plot(grid=False, label='Limiar Superior (eixo y à esquerda)')
ax3 = df.cdown1.plot(grid=False, label='Limiar Inferior (eixo y à esquerda)')
#ax3 = df.nup.plot(grid=False, label='Rede up')
#ax3 = df.ndown.plot(grid=False, label='Rede down')

#plt.vlines(x=46, ymin=0, ymax=73, ls='--', label='Pontos onde uma VM é alocada')
#plt.vlines(x=75, ymin=0, ymax=73, ls='--')
#plt.vlines(x=60, ymin=0, ymax=160, ls='--', color='red', label='Pontos onde uma VM é desalocada')
#plt.vlines(x=87, ymin=0, ymax=160, ls='--', color='red')

#up
plt.plot(6,55,'ro', label='Possível Alocação de VM')
plt.plot(7,56,'ro')
plt.plot(8,70,'ro') 
#dow
plt.plot(17,32,'bo', label='Possível Desalocação de VM')
plt.plot(18,0,'bo')
plt.plot(19,0,'bo')
#up
plt.plot(34,86,'ro')
plt.plot(35,75,'ro')
#plt.plot(35,41,'ro') 
#down
plt.plot(44,34,'bo')
plt.plot(45,0,'bo')
plt.plot(46,0,'bo') 
#up
plt.plot(58,54,'ro')
plt.plot(59,69,'ro')
plt.plot(60,100,'ro') 

#plt.plot(34,80, 'o', ms=40, markerfacecolor="None", markeredgecolor='yellow', markeredgewidth=3)
#plt.plot(0,80, 'o', ms=8, markerfacecolor="None", markeredgecolor='yellow', markeredgewidth=3, label='Combinação de Métricas')

ax4 = df.vms1.plot(secondary_y=True, label='VMs (eixo y à direita)')
ax4.set_ylim(bottom=0)
ax4.set_ylim(top=6)

plt.ylabel("Número de VMs")
plt.gca().yaxis.set_major_locator(mticker.MultipleLocator(1))

h1, l1 = ax3.get_legend_handles_labels()
h2, l2 = ax4.get_legend_handles_labels()




#plt.legend(h1+h2, l1+l2, bbox_to_anchor=(0.0, 0.0))
plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(1.20, 1), ncol=1)
#plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=6)
#plt.legend(h1, l1, loc='upper center', bbox_to_anchor=(0.5, -0.22), ncol=7)



plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# create dummy pandas dataframes
pd1 = df
#create subplot figure with having two side by side plots
fig, axes = plt.subplots(nrows=1,ncols=2,figsize=(12,2.5))
# plot first pandas frame in subplot style
pd1.plot(ax = axes[0], color=['purple', 'darkblue', 'yellow'])
pd1.vms1.plot(secondary_y=True)
# plot second pandas frame in subplot style
axes[0].get_legend().remove()
axes[0].set_xlabel('Tempo de Execução (minutos)')
axes[0].set_ylabel('Utilização de CPU')
axes[1].set_xlabel('Tempo de Execução (minutos)')
axes[1].set_ylabel('Consumo de Rede')

pd1.plot(ax = axes[1])
pd1.vms1.plot(secondary_y=True)

h1, l1 = axes[0].get_legend_handles_labels()
h2, l2 = axes[1].get_legend_handles_labels()

#plt.legend(h1+h2, l1+l2, bbox_to_anchor=(0.0, 0.0))
plt.legend(h1+h2, l1+l2, loc='upper center', bbox_to_anchor=(-0.1, -0.22), ncol=6)

plt.show()
